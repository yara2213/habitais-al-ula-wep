# %%
<html lang="en">

<head>
<meta charset="utf-8" />
<meta name="viewport" content="width=device-width" />
<title>our Habitas Al-ula</title>
<link href="css wep.css" rel="stylesheet" type="text/css" />
</head>

<body>
  
    <img src="C:\Users\yoyow\OneDrive\سطح المكتب\final project wep\back main.gif" width="100%">

     <div class="contact">
       <a href="contact.html" class="btn">CONTACT</a>
     </div>
    <div class="button">
        <br>
        <br><a href="Hotel Reservation Form.html" class="btn">Book now</a>
        <br>
        <br>
        <br>
        <a href="form log in.html" class="btn">log in</a>
        
        <a href="form sing up.html" class="btn">sing up</a>
    </div>
    
  

<!-- Below is your custom application script -->
<script src="script wep.js"></script>


</body>
</html>

# %%
page{log in ,,,sing up}


body{

margin: 0;
   padding: 0;
   border: 2px solid rgb(106, 55, 14);
   background-image: url(back\ form.jpeg);
   background-size: 100% 100%;
   background-position: center;
   display: flex;
   justify-content: center;
   align-items: center;
   height: 100vh;
   
   animation: bganimation 15s infinite
   
}

form{
    
    background-color: rgba(137, 126, 126, 0.372);
    padding:30px;
    width: 80%;
    color: white;
}
form input{

    background-color: rgba(34, 150, 150, 0.368);
    color: white;
    padding: 5px 10px;

}

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    
    <title>contact</title>
</head>
<body>
   <img src="contact.jpeg" width="100%">
</body>
</html>

# %%
page [[[main]]]


body
{
   margin: 0;
   padding: 0;
   border: 2px solid rgb(106, 55, 14);
   background-size: 100% 100%;
   background-position: center;
   animation: bganimation 15s infinite
   
   
}
.contact{
    
    
    
    position: absolute;
    top:90%;
    left: 20%;
    transform: translate(-50%, -50%);
  

}
.button
{
  
  position: absolute;
  top: 75%;
  left: 50%;
  transform: translate(-50%, -50%);
   
}
.btn {
    border: 3px solid rgba(90, 62, 6, 0.489);
   padding: 5px 20px;
   color: whitesmoke;
   transition: 0.5 ease;
   font-size: 30px;
}

# %%
<html lang="en">

<head>
<meta charset="utf-8" />
<title>sign up</title>
<link href="css sign up.css" rel="stylesheet" type="text/css" />
</head>
<body>
    <form>
        <fieldset>
            <legend>sign up</legend>
        <label>First name:<input type="text" name="fname"></label><br><br>
        <label>Middle name: <input type="text" name="lname"></label><br><br>
        <label>Last name: <input type="text" name="lname"></label><br><br>
        <label>gender</label><br><br>
        <input type="radio" name="male">male
        <input type="radio" name="female">female<br><br>
        <label>old:</label><br><input type="number" min="18" max="100"><br><br>
        <label> E-mai:</label><br><input type="email" name="email"><br><br>
        <label>password</label><br><input type="password" name="pass"><br><br>
        <label>confirm password</label><br><input type="password" name="pass"><br><br>
        <label>phone number</label><br><input type="tel" name="phone number"><br><br>
        <label for="register_country" class="label">select country</label><br><br>
        <select name="country" id="register_country">
            <option value="KSA">Saudi Arabia</option>
            <option value="UAE">Emirate</option>
            <option value="KWT">Kuwait</option>
            <option value="USA">America</option>
            <option value="IT">Italy</option>
            <option value="ES">Spain</option>
            <option value="other">other</option>
        </select><br><br>
        <p>
        <p>
        <p>
        <input type="submit" value="sign up">
    
            
        </fieldset>
    </form>
    


<!-- Below is your custom application script -->
<script src="script sign up.js"></script>

</body>
</html>

# %%
<html lang="en">

<head>
<meta charset="utf-8" />
<title>log in</title>
<link href="css log in.css" rel="stylesheet" type="text/css" />
</head>
<body>
    <form >
        <fieldset>
        <legend>log in</legend>
    
        <label> E-mai:<input type="email" name="email"></label><br><br>
    
        <label>password:<input type="password" name="pass"></label><br>
        
          
        <button>log in</button>
        </fieldset>
    </form>


<!-- Below is your custom application script -->
<script src="script log in.js"></script>

</body>
</html>
